# %%
import sys
import os

sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..', 'wlcstat-master')))

import wlcstat.chromo

sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..', 'stochastic-gene-conf-master')))

figure_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'subfigures/'))
data_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'data/'))

from stochastic_gene_conf import gene_conf
from stochastic_gene_conf import gene_analysis

import numpy as np
import numpy.matlib
import matplotlib
import matplotlib.pyplot as plt
import pickle
from scipy.signal import find_peaks

# %%
location_df = {}
signal_df = {}
starts_df = {}
ends_df = {}
cdf_df = {}

gene_name = []
k = 0

with open(os.path.join(data_path, 'CXCL9/unstim/variables.pkl'), 'rb') as file:
    temp = pickle.load(file)
    location = temp[0]
    signal = temp[1]
    Gene_start = temp[2]
    Gene_end = temp[3]
    TSS_vec = temp[4]
    accessible_starts = temp[5]
    accessible_ends = temp[6]
    cdf = temp[7]
    half_wrap = temp[8]
    
location_df[k] = location
signal_df[k] = signal
starts_df[k] = accessible_starts
ends_df[k] = accessible_ends
cdf_df[k] = cdf
k += 1
gene_name=np.append(gene_name,"CXCL9_0hr")

with open(os.path.join(data_path, 'CXCL9/lps_1h/variables.pkl'), 'rb') as file:
    temp = pickle.load(file)
    location = temp[0]
    signal = temp[1]
    Gene_start = temp[2]
    Gene_end = temp[3]
    TSS_vec = temp[4]
    accessible_starts = temp[5]
    accessible_ends = temp[6]
    cdf = temp[7]
    half_wrap = temp[8]
    
location_df[k] = location
signal_df[k] = signal
starts_df[k] = accessible_starts
ends_df[k] = accessible_ends
cdf_df[k] = cdf
k += 1
gene_name=np.append(gene_name,"CXCL9_1hr")


with open(os.path.join(data_path, 'IL6/unstim/variables.pkl'), 'rb') as file:
    temp = pickle.load(file)
    location = temp[0]
    signal = temp[1]
    Gene_start = temp[2]
    Gene_end = temp[3]
    TSS_vec = temp[4]
    accessible_starts = temp[5]
    accessible_ends = temp[6]
    cdf = temp[7]
    half_wrap = temp[8]
    
location_df[k] = location
signal_df[k] = signal
starts_df[k] = accessible_starts
ends_df[k] = accessible_ends
cdf_df[k] = cdf
k += 1
gene_name=np.append(gene_name,"IL6_0hr")

with open(os.path.join(data_path, 'IL6/lps_1h/variables.pkl'), 'rb') as file:
    temp = pickle.load(file)
    location = temp[0]
    signal = temp[1]
    Gene_start = temp[2]
    Gene_end = temp[3]
    TSS_vec = temp[4]
    accessible_starts = temp[5]
    accessible_ends = temp[6]
    cdf = temp[7]
    half_wrap = temp[8]
    
location_df[k] = location
signal_df[k] = signal
starts_df[k] = accessible_starts
ends_df[k] = accessible_ends
cdf_df[k] = cdf
k += 1
gene_name=np.append(gene_name,"IL6_1hr")


with open(os.path.join(data_path, 'CXCL10/unstim/variables.pkl'), 'rb') as file:
    temp = pickle.load(file)
    location = temp[0]
    signal = temp[1]
    Gene_start = temp[2]
    Gene_end = temp[3]
    TSS_vec = temp[4]
    accessible_starts = temp[5]
    accessible_ends = temp[6]
    cdf = temp[7]
    half_wrap = temp[8]
    
location_df[k] = location
signal_df[k] = signal
starts_df[k] = accessible_starts
ends_df[k] = accessible_ends
cdf_df[k] = cdf
k += 1
gene_name=np.append(gene_name,"CXCL10_0hr")

with open(os.path.join(data_path, 'CXCL10/lps_1h/variables.pkl'), 'rb') as file:
    temp = pickle.load(file)
    location = temp[0]
    signal = temp[1]
    Gene_start = temp[2]
    Gene_end = temp[3]
    TSS_vec = temp[4]
    accessible_starts = temp[5]
    accessible_ends = temp[6]
    cdf = temp[7]
    half_wrap = temp[8]
    
location_df[k] = location
signal_df[k] = signal
starts_df[k] = accessible_starts
ends_df[k] = accessible_ends
cdf_df[k] = cdf
k += 1
gene_name=np.append(gene_name,"CXCL10_1hr")


with open(os.path.join(data_path, 'IL15/unstim/variables.pkl'), 'rb') as file:
    temp = pickle.load(file)
    location = temp[0]
    signal = temp[1]
    Gene_start = temp[2]
    Gene_end = temp[3]
    TSS_vec = temp[4]
    accessible_starts = temp[5]
    accessible_ends = temp[6]
    cdf = temp[7]
    half_wrap = temp[8]
    
location_df[k] = location
signal_df[k] = signal
starts_df[k] = accessible_starts
ends_df[k] = accessible_ends
cdf_df[k] = cdf
k += 1
gene_name=np.append(gene_name,"IL15_0hr")

with open(os.path.join(data_path, 'IL15/lps_1h/variables.pkl'), 'rb') as file:
    temp = pickle.load(file)
    location = temp[0]
    signal = temp[1]
    Gene_start = temp[2]
    Gene_end = temp[3]
    TSS_vec = temp[4]
    accessible_starts = temp[5]
    accessible_ends = temp[6]
    cdf = temp[7]
    half_wrap = temp[8]
    
location_df[k] = location
signal_df[k] = signal
starts_df[k] = accessible_starts
ends_df[k] = accessible_ends
cdf_df[k] = cdf
k += 1
gene_name=np.append(gene_name,"IL15_1hr")

# %%
plt.figure(figsize=(20,40))
font = {'family' : 'serif',
    'weight':'normal',
    'size': 18}
plt.rc('font', **font)

for k in range(8):
    
    plt.subplot(4,2,int(k+1))

    plt.plot(location_df[k],signal_df[k]/np.max(signal_df[k]))
    plt.xlabel("Genome Location")
    plt.ylabel("NucleoATAC Signal")

    plt.xlim([location_df[k][0],location_df[k][-1]])
    plt.title(gene_name[k])

plt.tight_layout()

plt.draw()
plt.savefig(os.path.join(figure_path, r"allgene_nucleoATAC.pdf"), transparent=True)

plt.show()

# %%
peaks_df = {}

for k in range(8):

    peaks = find_peaks(signal_df[k],distance = 2*half_wrap+1,height = 1e-10)[0]
    peaks_df[k] = peaks

# %%
plt.figure(figsize=(10,24))
font = {'family' : 'serif',
    'weight':'normal',
    'size': 18}
plt.rc('font', **font)

for k in range(8):
    plt.subplot(4,2,int(k+1))

    plt.hist(signal_df[k][peaks_df[k]]/np.max(signal_df[k]),density=True,edgecolor='k')
    plt.plot(np.median(signal_df[k][peaks_df[k]]/np.max(signal_df[k]))*np.ones(2),[0,3.1],'k-',linewidth=3)
    plt.xlabel('NucleoATAC Peak Heights')
    plt.title(gene_name[k])
plt.tight_layout()
plt.draw()
plt.savefig(os.path.join(figure_path, r"nucleoatac_peaks_histogram.pdf"), transparent=True)
plt.show()

# %%
all_peak_heights = []

for k in range(8):
    all_peak_heights = np.append(all_peak_heights,signal_df[k][peaks_df[k]]/np.max(signal_df[k]))
    
plt.figure(figsize=(5,6))
font = {'family' : 'serif',
    'weight':'normal',
    'size': 18}
plt.rc('font', **font)

plt.hist(all_peak_heights,20,density=True,edgecolor='k')
plt.plot(np.median(all_peak_heights)*np.ones(2),[0,3.1],'k-',linewidth=3)
plt.xlim([0,1])
plt.xlabel('NucleoATAC Peak Heights')
plt.title('All Genes Histogram')

plt.tight_layout()
plt.draw()
plt.savefig(os.path.join(figure_path, r"nucleoatac_all_peaks_histogram.pdf"), transparent=True)
plt.show()

# %%
M = 1000

signal_min_low_df = {}
signal_vals_low_df = {}
nucs_idx_low_df = {}
N_nucs_low_df = {}
peak_nuc_counts_low_df = {}

signal_min_mid_df = {}
signal_vals_mid_df = {}
nucs_idx_mid_df = {}
N_nucs_mid_df = {}
peak_nuc_counts_mid_df = {}

signal_min_high_df = {}
signal_vals_high_df = {}
nucs_idx_high_df = {}
N_nucs_high_df = {}
peak_nuc_counts_high_df = {}


for k in range(8):

    signal_min_low = np.zeros(M)
    signal_vals_low = []
    nucs_idx_low = []
    N_nucs_low = np.zeros(M)

    signal_min_mid = np.zeros(M)
    signal_vals_mid = []
    nucs_idx_mid = []
    N_nucs_mid = np.zeros(M)


    signal_min_high = np.zeros(M)
    signal_vals_high = []
    nucs_idx_high = []
    N_nucs_high = np.zeros(M)

    peak_nuc_counts_low = np.zeros(len(peaks_df[k]))
    peak_nuc_counts_mid = np.zeros(len(peaks_df[k]))
    peak_nuc_counts_high = np.zeros(len(peaks_df[k]))


    for m in range(M):

        nucs = []

        break_con = False

        for i in range(len(peaks_df[k])):
            rand_val = np.random.uniform()
            if i != 0:
                j = 0
                while (np.abs(location_df[k][(np.abs(cdf_df[k]-rand_val)).argmin()]-nucs).min() <= 2*half_wrap+1) and (not break_con):
                    rand_val = np.random.uniform()
                    j += 1
                    if j > 1000:
                        break_con = True
            if (not break_con):
                nucs = np.append(nucs,(np.abs(cdf_df[k]-rand_val)).argmin())
            else:
                break

        nucs_low = nucs[0:int(np.min([len(nucs),len(peaks_df[k])/4]))].astype(int)
        nucs_mid = nucs[0:int(np.min([len(nucs),len(peaks_df[k])/2]))].astype(int)
        nucs_high = nucs.astype(int)

        nucs_idx_low = np.append(nucs_idx_low,nucs_low)
        signal_vals_low = np.append(signal_vals_low,signal_df[k][nucs_low])
        signal_min_low[m] = np.min(signal_df[k][nucs_low])
        N_nucs_low[m] = len(nucs[0:int(np.min([len(nucs),len(peaks_df[k])/4]))])

        nucs_idx_mid = np.append(nucs_idx_mid,nucs_mid)
        signal_vals_mid = np.append(signal_vals_mid,signal_df[k][nucs_mid])
        signal_min_mid[m] = np.min(signal_df[k][nucs_mid])
        N_nucs_mid[m] = len(nucs[0:int(np.min([len(nucs),len(peaks_df[k])/2]))])

        nucs_idx_high = np.append(nucs_idx_high,nucs_high)
        signal_vals_high = np.append(signal_vals_high,signal_df[k][nucs_high])
        signal_min_high[m] = np.min(signal_df[k][nucs_high])
        N_nucs_high[m] = len(nucs)


        temp = np.zeros(len(peaks_df[k]))
        for j in range(len(nucs_low)):
            jx = np.argmin(np.abs(location_df[k][peaks_df[k]]-location_df[k][nucs_low[j].astype(int)]))
            if temp[jx] == 0:
                peak_nuc_counts_low[jx] += 1/M
                temp[jx] = 1
        temp = np.zeros(len(peaks_df[k]))
        for j in range(len(nucs_mid)):
            jx = np.argmin(np.abs(location_df[k][peaks_df[k]]-location_df[k][nucs_mid[j].astype(int)]))
            if temp[jx] == 0:
                peak_nuc_counts_mid[jx] += 1/M
                temp[jx] = 1
        temp = np.zeros(len(peaks_df[k]))
        for j in range(len(nucs_high)):
            jx = np.argmin(np.abs(location_df[k][peaks_df[k]]-location_df[k][nucs_high[j].astype(int)]))
            if temp[jx] == 0:
                peak_nuc_counts_high[jx] += 1/M
                temp[jx] = 1
                
    signal_min_low_df[k] = signal_min_low
    signal_vals_low_df[k] = signal_vals_low
    nucs_idx_low_df[k] = nucs_idx_low
    N_nucs_low_df[k] = N_nucs_low
    peak_nuc_counts_low_df[k] = peak_nuc_counts_low

    signal_min_mid_df[k] = signal_min_mid
    signal_vals_mid_df[k] = signal_vals_mid
    nucs_idx_mid_df[k] =  nucs_idx_mid
    N_nucs_mid_df[k] = N_nucs_mid
    peak_nuc_counts_mid_df[k] = peak_nuc_counts_mid

    signal_min_high_df[k] = signal_min_high
    signal_vals_high_df[k] = signal_vals_high
    nucs_idx_high_df[k] = nucs_idx_high
    N_nucs_high_df[k] = N_nucs_high
    peak_nuc_counts_high_df[k] = peak_nuc_counts_high

# %%
fig, ax = plt.subplots(4,2) 
font = {'family' : 'serif',
    'weight':'normal',
    'size': 18}
plt.rc('font', **font)
plt.rcParams["figure.figsize"] = (20,20)

k = 0
for i in range(4):
    for j in range(2):
        ax[i,j].hist(nucs_idx_high_df[k],density=True,edgecolor='k',facecolor='b',alpha=1.0,bins=np.arange(0,500000,10000))
        ax[i,j].set_title(gene_name[k])
        ax[i,j].set_xlim([0,500000])
        k+=1
        
ax00 = ax[0,0].twinx()
ax01 = ax[0,1].twinx()
ax10 = ax[1,0].twinx()
ax11 = ax[1,1].twinx()
ax20 = ax[2,0].twinx()
ax21 = ax[2,1].twinx()
ax30 = ax[3,0].twinx()
ax31 = ax[3,1].twinx()

ax00.plot(signal_df[0]/np.max(signal_df[0]),'r-',linewidth=4)
ax01.plot(signal_df[1]/np.max(signal_df[1]),'r-',linewidth=4)
ax10.plot(signal_df[2]/np.max(signal_df[2]),'r-',linewidth=4)
ax11.plot(signal_df[3]/np.max(signal_df[3]),'r-',linewidth=4)
ax20.plot(signal_df[4]/np.max(signal_df[4]),'r-',linewidth=4)
ax21.plot(signal_df[5]/np.max(signal_df[5]),'r-',linewidth=4)
ax30.plot(signal_df[6]/np.max(signal_df[6]),'r-',linewidth=4)
ax31.plot(signal_df[7]/np.max(signal_df[7]),'r-',linewidth=4)
ax00.set_ylim([0,1])
ax01.set_ylim([0,1])
ax10.set_ylim([0,1])
ax11.set_ylim([0,1])
ax20.set_ylim([0,1])
ax21.set_ylim([0,1])
ax30.set_ylim([0,1])
ax31.set_ylim([0,1])
# plt.tight_layout()
plt.draw()
plt.savefig(os.path.join(figure_path, r"nucleoatac_signal_and_hists.pdf"), transparent=True)
plt.show()

# %%
def f(x, b, n): 
    return x ** n  / (x ** n + b)

y_low_df = {}
y_mid_df = {}
y_high_df = {}

plt.figure(figsize=(20,20))
font = {'family' : 'serif',
    'weight':'normal',
    'size': 18}
plt.rc('font', **font)

for k in range(8):

    I = np.argsort(signal_df[k][peaks_df[k]])

    plt.subplot(4,2,int(k+1))

    plt.plot(signal_df[k][peaks_df[k]][I]/np.max(signal_df[k]),peak_nuc_counts_high_df[k][I],'b.')
    
    
    plt.plot(np.sort(signal_df[k][peaks_df[k]]/np.max(signal_df[k])),np.arange(len(signal_df[k][peaks_df[k]])) / (len(signal_df[k][peaks_df[k]]) - 1),'k-')
    plt.plot(np.median(signal_df[k][peaks_df[k]]/np.max(signal_df[k]))*np.ones(2),[0,0.5],'k--')
    plt.ylim([0,1])
    plt.xlim([0,1])
    plt.title(gene_name[k])
plt.tight_layout()
plt.draw()
plt.savefig(os.path.join(figure_path, r"nucleoatac_occupancy_probs.pdf"), transparent=True)
plt.show()

# %%
plt.figure(figsize=(10,8))
font = {'family' : 'serif',
    'weight':'normal',
    'size': 18}
plt.rc('font', **font)

x_fine = np.linspace(0,1,1001)

xtemp = []
ytemp = []

for k in range(8):
    plt.plot(signal_df[k][peaks_df[k]]/np.max(signal_df[k]),peak_nuc_counts_high_df[k],'b.',alpha=0.25)

plt.plot(np.sort(all_peak_heights),np.arange(len(all_peak_heights)) / (len(all_peak_heights) - 1),'k-')
plt.plot(np.median(all_peak_heights)*np.ones(2),[0,0.5],'k--')

plt.ylim([0,1])
plt.xlim([1e-3,1])
plt.xlabel('NucleoATAC Peak Signal Value')
plt.ylabel('Nuc Occupancy Probability')
plt.title("All Gene Avg")
plt.tight_layout()
plt.draw()
plt.savefig(os.path.join(figure_path, r"allgene_nucleoatac_occupancy_probs.pdf"), transparent=True)
plt.show()
